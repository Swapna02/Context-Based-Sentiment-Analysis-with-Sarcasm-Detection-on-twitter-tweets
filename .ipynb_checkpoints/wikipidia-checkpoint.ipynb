# %%
import pandas as pd
import wikipedia as wp

# %%
sports_list = ["sport","cricket","football","basketball","wrestling","kabaddi","hockey","Game"]
politics_list = ["Politics","Politician","Democratic republic","Legislature","Parliament","Election","Government","President (government title)","Policy","Republic","Governance","Prime Minister of India"]
terrorism_list = ["Terrorism","War","Violence","Jihad","Al-Qaeda"]

# %%
def get_data(parameter):
    var_data = []
    for i in parameter:
        data1 = wp.page(i)

        s = ""
        for character in data1.content:
            if character != '(' or character != ')' :
                s = s + character
            if(character == '.' or character == '\n'):
                if (len(s) >= 60):
                    var_data.append(s)
                s = ""
    return var_data

# %%
list1 = get_data(sports_list)

# %%
list1
# Out:
# ['Sport pertains to any form of competitive physical activity or game that aims to use, maintain or improve physical ability and skills while providing enjoyment to participants and, in some cases, entertainment to spectators.',
#  " Sports can, through casual or organized participation, improve one's physical health.",
#  ' Hundreds of sports exist, from those between single contestants, through to those with hundreds of simultaneous participants, either in teams or competing as individuals.',
#  ' In certain sports such as racing, many contestants may compete, simultaneously or consecutively, with one winner; in others, the contest (a match) is between two sides, each attempting to exceed the other.',
#  ' Some sports allow a "tie" or "draw", in which there is no single winner; others provide tie-breaking methods to ensure one winner and one loser.',
#  ' A number of contests may be arranged in a tournament producing a champion.',
# ...

# %%
list2 = get_data(politics_list)

# %%
list2
# Out:
# ["Politics (from Greek: Πολιτικά, politiká, 'affairs of the cities') is the set of activities that are associated with making decisions in groups, or other forms of power relations between individuals, such as the distribution of resources or status.",
#  ' The branch of social science that studies politics is referred to as political science.',
#  'It may be used positively in the context of a "political solution" which is compromising and non-violent, or descriptively as "the art or science of government", but also often carries a negative connotation.',
#  ' For example, abolitionist Wendell Phillips declared that "we do not play politics; anti-slavery is no half-jest with us.',
#  '" The concept has been defined in various ways, and different approaches have fundamentally differing views on whether it should be used extensively or limitedly, empirically or normatively, and on whether conflict or co-operation is more essential to it.',
# ...

# %%
list3 = get_data(terrorism_list)

# %%
list3
# Out:
# ['Terrorism is, in the broadest sense, the use of intentional violence to achieve political aims.',
#  ' It is used in this regard primarily to refer to violence during peacetime or in the context of war against non-combatants (mostly civilians and neutral military personnel).',
#  ' The terms "terrorist" and "terrorism" originated during the French Revolution of the late 18th century but became widely used internationally and gained worldwide attention in the 1970s during the conflicts of Northern Ireland, the Basque Country, and the Israeli–Palestinian conflict.',
#  ' The increased use of suicide attacks from the 1980s onwards was typified by the September 11 attacks in New York City, Arlington and Pennsylvania in 2001.',
#  'There are various different definitions of terrorism, with no universal agreement about it.',
#  ' It is often used with the connotation of something that is "morally wrong".',
# ...

# %%
df1 = pd.DataFrame(list1)
df1.to_csv("1sports_csv.csv",index=False)
df2 = pd.DataFrame(list2)
df2.to_csv("2politics_csv.csv",index=False)
df3 = pd.DataFrame(list3)
df3.to_csv("3terrorism_csv.csv",index=False)

# %%
data1 = pd.read_csv("1sports_csv.csv")
data1["category"] = "sports"
data1.rename(columns={'0': 'data'}, inplace=True)
data1
# Out:
#                                                    data category
# 0     Sport pertains to any form of competitive phys...   sports
# 1      Sports can, through casual or organized parti...   sports
# 2      Hundreds of sports exist, from those between ...   sports
# 3      In certain sports such as racing, many contes...   sports
# 4      Some sports allow a "tie" or "draw", in which...   sports
# ...                                                 ...      ...
# 1768  Business games can take a variety of forms, fr...   sports
# 1769   The purpose of these games is to link to some...   sports
# 1770   Some of these are computer simulations while ...   sports
# 1771  The term "game" can include simulation or re-e...   sports
# 1772   The root of this meaning may originate in the...   sports
#
# [1773 rows x 2 columns]

# %%
data2 = pd.read_csv("2politics_csv.csv")
data2["category"] = "politics"
data2.rename(columns={'0': 'data'}, inplace=True)
data2
# Out:
#                                                    data  category
# 0     Politics (from Greek: Πολιτικά, politiká, 'aff...  politics
# 1      The branch of social science that studies pol...  politics
# 2     It may be used positively in the context of a ...  politics
# 3      For example, abolitionist Wendell Phillips de...  politics
# 4     " The concept has been defined in various ways...  politics
# ...                                                 ...       ...
# 1801   There is neither constitutional requirement f...  politics
# 1802   Typically, senior cabinet ministers like the ...  politics
# 1803   The post is considered to be the senior most ...  politics
# 1804   Generally, deputy prime ministers have been a...  politics
# 1805   The first holder of this post was Vallabhbhai...  politics
#
# [1806 rows x 2 columns]

# %%
data3 = pd.read_csv("3terrorism_csv.csv")
data3["category"] = "terrorism"
data3.rename(columns={'0': 'data'}, inplace=True)
data3
# Out:
#                                                    data   category
# 0     Terrorism is, in the broadest sense, the use o...  terrorism
# 1      It is used in this regard primarily to refer ...  terrorism
# 2      The terms "terrorist" and "terrorism" origina...  terrorism
# 3      The increased use of suicide attacks from the...  terrorism
# 4     There are various different definitions of ter...  terrorism
# ...                                                 ...        ...
# 1832  In mid-2014 after the Islamic State of Iraq an...  terrorism
# 1833  " The speech included a religious refutation o...  terrorism
# 1834  " He also recalled a past instance in which Os...  terrorism
# 1835   Zawahiri was encouraging factionalism and div...  terrorism
# 1836  17 de-classified documents captured during the...  terrorism
#
# [1837 rows x 2 columns]

# %%
data1[207:]
# Out:
#                                                    data category
# 207    Bowling underwent an evolution around 1760 wh...   sports
# 208    This caused a revolution in bat design becaus...   sports
# 209   The Hambledon Club was founded in the 1760s an...   sports
# 210    MCC quickly became the sport's premier club a...   sports
# 211    New Laws introduced in the latter part of the...   sports
# ...                                                 ...      ...
# 1768  Business games can take a variety of forms, fr...   sports
# 1769   The purpose of these games is to link to some...   sports
# 1770   Some of these are computer simulations while ...   sports
# 1771  The term "game" can include simulation or re-e...   sports
# 1772   The root of this meaning may originate in the...   sports
#
# [1566 rows x 2 columns]

# %%
data2[1325:]
# Out:
#                                                    data  category
# 1325   The 20th century saw republicanism become an ...  politics
# 1326   Some nations, such as Indonesia and Azerbaija...  politics
# 1327   In Iran, the 1979 revolution overthrew the mo...  politics
# 1328  With no monarch, most modern republics use the...  politics
# 1329   Originally used to refer to the presiding off...  politics
# ...                                                 ...       ...
# 1801   There is neither constitutional requirement f...  politics
# 1802   Typically, senior cabinet ministers like the ...  politics
# 1803   The post is considered to be the senior most ...  politics
# 1804   Generally, deputy prime ministers have been a...  politics
# 1805   The first holder of this post was Vallabhbhai...  politics
#
# [481 rows x 2 columns]

# %%
data3[1631:]
# Out:
#                                                    data   category
# 1631   He was quoted as saying, "Is there really an ...  terrorism
# 1632  "Following the mass protests that took place i...  terrorism
# 1633   Before the Syrian Civil War, al-Qaeda's prese...  terrorism
# 1634   Groups such as the al-Nusra Front and the Isl...  terrorism
# 1635   Ideologically, the Syrian Civil War has serve...  terrorism
# ...                                                 ...        ...
# 1832  In mid-2014 after the Islamic State of Iraq an...  terrorism
# 1833  " The speech included a religious refutation o...  terrorism
# 1834  " He also recalled a past instance in which Os...  terrorism
# 1835   Zawahiri was encouraging factionalism and div...  terrorism
# 1836  17 de-classified documents captured during the...  terrorism
#
# [206 rows x 2 columns]

# %%
combined_csv = pd.concat([data1,data2,data3])

# %%
len(combined_csv)
# Out:
# 5416

# %%
print(len(data1),len(data2),len(data3))
# Out:
# 1773 1806 1837

# %%
combined_csv[5036:5038]
# Out:
#                                                    data   category
# 1457   These alleged apostates included leaders of M...  terrorism
# 1458  The Afghan jihad against the pro-Soviet govern...  terrorism

# %%
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
df=pd.read_csv('combined_csv.csv')

# %%
df[5036:5039]
# Out:
#                                                    data   category
# 5036   These alleged apostates included leaders of M...  terrorism
# 5037  The Afghan jihad against the pro-Soviet govern...  terrorism
# 5038  While the leadership's own theological platfor...  terrorism

# %%
len(combined_csv)
# Out:
# 5416
